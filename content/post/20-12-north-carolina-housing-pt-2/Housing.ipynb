# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("NC_Housing_Prices_2018.csv")

# %%
df
# Out:
#       population  households  median_income  median_house_value  \
# 0            970         384        38542.0             82100.0
# 1           1019         383        30625.0            107900.0
# 2           1040         552        19318.0             90800.0
# 3           1690         693        30478.0             81800.0
# 4            424         232        20667.0             74800.0
# ...          ...         ...            ...                 ...
# 6150         858         418        25500.0            109300.0
# 6151        1030         392        31250.0            133000.0
# 6152        1281         608        26894.0            133000.0
# 6153        1643         613        43359.0            174300.0
# 6154        2185         894        44474.0            161700.0
#
#       total_bedrooms  total_rooms   latitude  longitude  housing_median_age
# 0                433          433  36.110297 -79.439579                50.0
# ...

# %%
df[df["total_bedrooms"]!=df["total_rooms"]]
# Out:
# Empty DataFrame
# Columns: [population, households, median_income, median_house_value, total_bedrooms, total_rooms, latitude, longitude, housing_median_age]
# Index: []

# %%
df = df[df["population"]>0]

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=df["population"]/100, label="Median House Value", figsize=(18,6),
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
sns.pairplot(df, vars=['population', 'households', 'median_income', 'median_house_value', 'total_bedrooms', 'total_rooms', 'housing_median_age'],
            diag_kind='kde')

# %%
df[df["housing_median_age"]>200].count()
# Out:
# population            58
# households            58
# median_income         56
# median_house_value    56
# total_bedrooms        58
# total_rooms           58
# latitude              58
# longitude             58
# housing_median_age    58
# dtype: int64

# %%
df[df["housing_median_age"]>200]
# Out:
#       population  households  median_income  median_house_value  \
# 49           492         283        29875.0            104300.0
# 381         1499         786        23646.0            636700.0
# 383          789         353        64750.0            422500.0
# 393         1321         678        43243.0            238900.0
# 398          681         417        52841.0            618100.0
# 419         1501         771        42423.0            153900.0
# 484         1922         744        57976.0            231900.0
# 501          788         354        58750.0            415500.0
# 510          722         294        70750.0            260600.0
# 527          576         371        36285.0            334400.0
# 645          996         456        42654.0             88500.0
# 666         1102         494        46786.0             88000.0
# 1643        1049         403        46174.0            172300.0
# 1644         894         375        72031.0            261800.0
# ...

# %%
# Out:
#       B01001_001E  B11001_001E  B19013_001E  B25077_001E  B25035_001E  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 6150          NaN          NaN          NaN          NaN          NaN
# 6151          NaN          NaN          NaN          NaN          NaN
# 6152          NaN          NaN          NaN          NaN          NaN
# 6153          NaN          NaN          NaN          NaN          NaN
# 6154          NaN          NaN          NaN          NaN          NaN
#
#       B25041_001E  B25017_001E NAME GEO_ID  state  county  tract  block group
# ...

# %%
raw = pd.read_csv("raw_census.csv")

# %%
raw["B25035_001E"].hist()

# %%
raw[(1 <= raw["B25035_001E"]) & (raw["B25035_001E"] <= 1500)]
# Out:
#       B01001_001E  B11001_001E  B19013_001E  B25077_001E  B25035_001E  \
# 3774          517          239        78750       297000           18
# 5501          907          337        35150       380000           18
#
#       B25041_001E  B25017_001E  \
# 3774          258          258
# 5501          390          390
#
#                                                    NAME  \
# 3774  Block Group 3, Census Tract 41, Mecklenburg Co...
# 5501  Block Group 2, Census Tract 509, Wake County, ...
#
#                      GEO_ID  state  county  tract  block group
# 3774  1500000US371190041003     37     119   4100            3
# 5501  1500000US371830509002     37     183  50900            2

# %%
raw[(raw["B25035_001E"]<0) & (raw["B25035_001E"] > -666666666 )]
# Out:
# Empty DataFrame
# Columns: [B01001_001E, B11001_001E, B19013_001E, B25077_001E, B25035_001E, B25041_001E, B25017_001E, NAME, GEO_ID, state, county, tract, block group]
# Index: []
